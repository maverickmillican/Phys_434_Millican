# %% [markdown]
# # Lab 1 - Maverick Millican

# %% [markdown]
# After a long and trying two hours of getting to understand the nuances of git and GitHub, this lab and using Jupyter are what I am really here to do. Let's begin.

# %%
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt

# %% [markdown]
# ## A Little Statistics

# %% [markdown]
# ### 1. A)
# I started by looking up the normal distribution, its properties, as well as the associated Z-table. The Z-table is a list of correlated standard deviations and probability sums from a Gaussian distribution with mean 0 and standard deviation 1. The Z values are the number of standard deviations in this type of distribution.  The Z-table is what I used to verify the X$\sigma$ values for some of the Gaussian and non-Gaussian distributions after applying PPF methods.  Below is the PDF of the Normal Distribution.
# ### ${\displaystyle {\frac {1}{\sigma {\sqrt {2\pi }}}}e^{-{\frac {1}{2}}\left({\frac {x-\mu }{\sigma }}\right)^{2}}}$

# %% [markdown]
# ### 1. B)

# %% [markdown]
# Now I will show a few plots of Normal distributions and their associated Cumulative Distribution Functions to certain values in order to show their adherence to the Z-table. The most common known values are for z = 1, 2, 3 that correspond to CDF values (after multiplying by 2 to account for $\pm$ z) of 0.6827, 0.9545, 0.9974 and I will check that here. \
# $  Z = \frac {X-\mu }{\sigma } $ \
# $X = $ x value to be integrated to \
# $\mu = $ mean value of distribution \
# $\sigma = $ standard deviation

# %% [markdown]
# Here, I integrate to the first 3 standard deviations using the Cumulative Distribution Function (CDF) to verify that the above percentages are in fact accurate.  I use different shades of purple to show the first three standard deviations in each plot, which correspond to Z = 1, 2, 3.
#
# You will see that there will be a lot of content relevant to the lab that is part of the "print" statements.

# %%
mu = 5; sigma = .01
d = stats.norm.rvs(loc = mu, scale = sigma, size = 100000)
fig, ax = plt.subplots(1, 1)
ax.set_title(f'\u03BC={mu}, \u03C3={sigma}')
ax.hist(d,50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
ax.set_xlim([mu-5*sigma,mu+5*sigma])
x = np.linspace(mu-5*sigma,mu+5*sigma,1000)
ax.plot(x,stats.norm.pdf(x,loc = 5., scale = 0.01),linewidth = 3,alpha = 0.5)
int_base3 = np.linspace(mu-3*sigma,mu+3*sigma,1000)
int_base2 = np.linspace(mu-2*sigma,mu+2*sigma,1000)
int_base1 = np.linspace(mu-1*sigma,mu+1*sigma,1000)
ax.fill_between(int_base1, stats.norm.pdf(int_base1,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
ax.fill_between(int_base2, stats.norm.pdf(int_base2,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
ax.fill_between(int_base3, stats.norm.pdf(int_base3,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
plt.yscale('log')
print(f' Z=1 P={1 - ((1 - stats.norm.cdf(mu+1*sigma, loc = mu, scale = sigma)) * 2):.4f},  Z=2 P={1 - ((1 - stats.norm.cdf(mu+2*sigma, loc = mu, scale = sigma)) * 2):.4f}, Z=3 P={1 - ((1 - stats.norm.cdf(mu+3*sigma, loc = mu, scale = sigma)) * 2):.4f}')
# Out:
#  Z=1 P=0.6827,  Z=2 P=0.9545, Z=3 P=0.9973

# %%
mu = 100; sigma = 18
d = stats.norm.rvs(loc = mu, scale = sigma, size = 100000)
fig, ax = plt.subplots(1, 1)
ax.set_title(f'\u03BC={mu}, \u03C3={sigma}')
ax.hist(d,50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
ax.set_xlim([mu-5*sigma,mu+5*sigma])
x = np.linspace(mu-5*sigma,mu+5*sigma,1000)
ax.plot(x,stats.norm.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
int_base3 = np.linspace(mu-3*sigma,mu+3*sigma,1000)
int_base2 = np.linspace(mu-2*sigma,mu+2*sigma,1000)
int_base1 = np.linspace(mu-1*sigma,mu+1*sigma,1000)
ax.fill_between(int_base1, stats.norm.pdf(int_base1,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
ax.fill_between(int_base2, stats.norm.pdf(int_base2,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
ax.fill_between(int_base3, stats.norm.pdf(int_base3,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
plt.yscale('log')
print(f' Z=1 P={1 - ((1 - stats.norm.cdf(mu+1*sigma, loc = mu, scale = sigma)) * 2):.4f},  Z=2 P={1 - ((1 - stats.norm.cdf(mu+2*sigma, loc = mu, scale = sigma)) * 2):.4f}, Z=3 P={1 - ((1 - stats.norm.cdf(mu+3*sigma, loc = mu, scale = sigma)) * 2):.4f}')
# Out:
#  Z=1 P=0.6827,  Z=2 P=0.9545, Z=3 P=0.9973

# %%
mu = 0; sigma = .5
d = stats.norm.rvs(loc = mu, scale = sigma, size = 100000)
fig, ax = plt.subplots(1, 1)
ax.set_title(f'\u03BC={mu}, \u03C3={sigma}')
ax.hist(d,50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
ax.set_xlim([mu-5*sigma,mu+5*sigma])
x = np.linspace(mu-5*sigma,mu+5*sigma,1000)
ax.plot(x,stats.norm.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
int_base3 = np.linspace(mu-3*sigma,mu+3*sigma,1000)
int_base2 = np.linspace(mu-2*sigma,mu+2*sigma,1000)
int_base1 = np.linspace(mu-1*sigma,mu+1*sigma,1000)
ax.fill_between(int_base1, stats.norm.pdf(int_base1,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
ax.fill_between(int_base2, stats.norm.pdf(int_base2,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
ax.fill_between(int_base3, stats.norm.pdf(int_base3,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
plt.yscale('log')
p1 = 1 - ((1 - stats.norm.cdf(mu+1*sigma, loc = mu, scale = sigma)) * 2)
p2 = 1 - ((1 - stats.norm.cdf(mu+2*sigma, loc = mu, scale = sigma)) * 2)
p3 = 1 - ((1 - stats.norm.cdf(mu+3*sigma, loc = mu, scale = sigma)) * 2)
print(f' Z=1 P={p1:.4f},  Z=2 P={p2:.4f}, Z=3 P={p3:.4f}')
# Out:
#  Z=1 P=0.6827,  Z=2 P=0.9545, Z=3 P=0.9973

# %% [markdown]
# ### 1. C)

# %% [markdown]
# Now, I will do the inverse. I am going to use the Percent Point Function (PPF) to verify that for different sets of data, I can find the correct Z-value. I am going to use the percentages that align with the Z-values of 1, 2, and 3 that are listed at the top.

# %%
mu = 5; sigma = .01
d = stats.norm.rvs(loc = mu, scale = sigma, size = 100000)
fig, ax = plt.subplots(1, 1)
ax.set_title(f'\u03BC={mu}, \u03C3={sigma}')
ax.hist(d,50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
ax.set_xlim([mu-5*sigma,mu+5*sigma])
x = np.linspace(mu-5*sigma,mu+5*sigma,1000)
ax.plot(x,stats.norm.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
int_base3 = np.linspace(mu-3*sigma,mu+3*sigma,1000)
int_base2 = np.linspace(mu-2*sigma,mu+2*sigma,1000)
int_base1 = np.linspace(mu-1*sigma,mu+1*sigma,1000)
ax.fill_between(int_base1, stats.norm.pdf(int_base1,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
ax.fill_between(int_base2, stats.norm.pdf(int_base2,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
ax.fill_between(int_base3, stats.norm.pdf(int_base3,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
plt.yscale('log')
z3 = ((stats.norm.ppf(1-(1-.9974)/2, loc = mu, scale = sigma)-mu)/sigma)
z2 = ((stats.norm.ppf(1-(1-.9545)/2, loc = mu, scale = sigma)-mu)/sigma)
z1 = ((stats.norm.ppf(1-(1-.6827)/2, loc = mu, scale = sigma)-mu)/sigma)
print(f' P=.9974 Z={z3:.4f},  P=.9545 Z={z2:.4f}, P=.6827 Z={z1:.4f}')
# Out:
#  P=.9974 Z=3.0115,  P=.9545 Z=2.0000, P=.6827 Z=1.0000

# %%
mu = 100; sigma = 18
d = stats.norm.rvs(loc = mu, scale = sigma, size = 100000)
fig, ax = plt.subplots(1, 1)
ax.set_title(f'\u03BC={mu}, \u03C3={sigma}')
ax.hist(d,50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
ax.set_xlim([mu-5*sigma,mu+5*sigma])
x = np.linspace(mu-5*sigma,mu+5*sigma,1000)
ax.plot(x,stats.norm.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
int_base3 = np.linspace(mu-3*sigma,mu+3*sigma,1000)
int_base2 = np.linspace(mu-2*sigma,mu+2*sigma,1000)
int_base1 = np.linspace(mu-1*sigma,mu+1*sigma,1000)
ax.fill_between(int_base1, stats.norm.pdf(int_base1,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
ax.fill_between(int_base2, stats.norm.pdf(int_base2,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
ax.fill_between(int_base3, stats.norm.pdf(int_base3,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
plt.yscale('log')
z3 = ((stats.norm.ppf(1-(1-.9974)/2, loc = mu, scale = sigma)-mu)/sigma)
z2 = ((stats.norm.ppf(1-(1-.9545)/2, loc = mu, scale = sigma)-mu)/sigma)
z1 = ((stats.norm.ppf(1-(1-.6827)/2, loc = mu, scale = sigma)-mu)/sigma)
print(f' P=.9974 Z={z3:.4f},  P=.9545 Z={z2:.4f}, P=.6827 Z={z1:.4f}')
# Out:
#  P=.9974 Z=3.0115,  P=.9545 Z=2.0000, P=.6827 Z=1.0000

# %%
mu = 0; sigma = .5
d = stats.norm.rvs(loc = mu, scale = sigma, size = 100000)
fig, ax = plt.subplots(1, 1)
ax.set_title(f'\u03BC={mu}, \u03C3={sigma}')
ax.hist(d,50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
ax.set_xlim([mu-5*sigma,mu+5*sigma])
x = np.linspace(mu-5*sigma,mu+5*sigma,1000)
ax.plot(x,stats.norm.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
int_base3 = np.linspace(mu-3*sigma,mu+3*sigma,1000)
int_base2 = np.linspace(mu-2*sigma,mu+2*sigma,1000)
int_base1 = np.linspace(mu-1*sigma,mu+1*sigma,1000)
ax.fill_between(int_base1, stats.norm.pdf(int_base1,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
ax.fill_between(int_base2, stats.norm.pdf(int_base2,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
ax.fill_between(int_base3, stats.norm.pdf(int_base3,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .2)
plt.yscale('log')
z3 = ((stats.norm.ppf(1-(1-.9974)/2, loc = mu, scale = sigma)-mu)/sigma)
z2 = ((stats.norm.ppf(1-(1-.9545)/2, loc = mu, scale = sigma)-mu)/sigma)
z1 = ((stats.norm.ppf(1-(1-.6827)/2, loc = mu, scale = sigma)-mu)/sigma)
print(f' P=.9974 Z={z3:.4f},  P=.9545 Z={z2:.4f}, P=.6827 Z={z1:.4f}')
# Out:
#  P=.9974 Z=3.0115,  P=.9545 Z=2.0000, P=.6827 Z=1.0000

# %% [markdown]
# ## 1. D)

# %% [markdown]
# The reason that no minus signs appeared in my calculations was becuase I was very careful to use the CDF function to come up with a percentage associated with the Z-value (can't be negative) and the PPF function to find the x-value at which the probability lies. My distributions all had positive centers and their distributions lied almost entirely within positive numbers, therefore the locaiton of the integration point must have been positive, and furthermore the Z-value. Had my distributions been in the negatives, or if the integration had stopped at a negative value of x, then the z-value would also be negative.

# %% [markdown]
# ## 2. A)

# %% [markdown]
# I decided to explore the exponential distribution which is the continous probability distribution of a Poission Point Process. This distribution shows the probability distribution of the time between events that occur independently of one another at a fixed or constant average rate. This distribution is used often to model and predict the likelihood of the radioactive decay in a material. Because the different atoms' decay is unrelated to each other and the decays happen at a relatively constant rate, the amount of time between decays can be represented as an exponential distribution. The PDF of the distribution is written as
# ### $\lambda e^{{-\lambda x}}$

# %% [markdown]
# ## 2. B)

# %% [markdown]
# Here I plot two different exponential distributions, I played with both the location and the scale of the distribution to see differences in how the data gets distributed.

# %%
mu = 0; sigma = .6
d = stats.expon.rvs(loc = mu, scale = sigma, size = 100000)
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(12,3))
ax.set_title(f'start={mu}, \u03C3={sigma}')
ax.hist(d, 50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
ax.set_xlim([mu,mu+8*sigma])
x = np.linspace(mu,mu+8*sigma,100000)
ax.plot(x,stats.expon.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
ax2.set_yscale('log')
ax2.set_title(f'start={mu}, \u03C3={sigma}')
ax2.hist(d, 50, density=True, color = 'r', alpha = .3)
ax2.tick_params(labelsize = 10)
ax2.set_xlim([mu,mu+8*sigma])
x = np.linspace(mu,mu+8*sigma,100000)
ax2.plot(x,stats.expon.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
ax2.set_ylabel("Counts (log-scale)", fontsize=12); ax.set_ylabel("Counts", fontsize = 12)
ax2.set_xlabel("X", fontsize=12); ax.set_xlabel("X", fontsize = 12)
# Out:
# Text(0.5, 0, 'X')

# %%
mu = 2; sigma = .2
d = stats.expon.rvs(loc = mu, scale = sigma, size = 100000)
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(12,3))
ax.set_title(f'start={mu}, \u03C3={sigma}')
ax.hist(d, 50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
ax.set_xlim([mu,mu+5*sigma])
x = np.linspace(mu,mu+5*sigma,100000)
ax.plot(x,stats.expon.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
ax2.set_yscale('log')
ax2.set_title(f'start={mu}, \u03C3={sigma}')
ax2.hist(d, 50, density=True, color = 'r', alpha = .3)
ax2.tick_params(labelsize = 10)
ax2.set_xlim([mu,mu+5*sigma])
x = np.linspace(mu,mu+5*sigma,100000)
ax2.plot(x,stats.expon.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
ax2.set_ylabel("Counts (log-scale)", fontsize=12); ax.set_ylabel("Counts", fontsize = 12)
ax2.set_xlabel("X-values", fontsize=12); ax.set_xlabel("X-values", fontsize = 12)
# Out:
# Text(0.5, 0, 'X-values')

# %% [markdown]
# Both distributions follow the same shape which is to be expected as they are created by a computer algorithm to make an exponential distribution. Notable features of the distribution are the long tail in the distribution (only on the right side) as well as the linear slope under a logarithmic y axis.

# %% [markdown]
# ## 3. A) and B)

# %% [markdown]
# Now I am assuming that my background noise represents an exponential distribution. I have arbitrarily decided that anything measured that has a value of 1.8 or greater using the first set of parameters and 2.85 or greater for the second is to be considered signal like. The question to be answered is as follows: "What is the probability that the base noise will appear as a signal to the detector?"

# %% [markdown]
# ## 3. C)

# %% [markdown]
# Use $[1 - \int _{0}^{1.8,\;or \; 2.85} pdf(x)dx] $ in order to find the probability that the signal will appear signal like. Or just use the built in CDF function like I have used below. I shade (in purple) the points of which would not appear to be signal like, leaving the rest of the distribution to be a possible false signal.

# %% [markdown]
# ## 3. D) and E)

# %%
mu = 0; sigma = .6
d = stats.expon.rvs(loc = mu, scale = sigma, size = 100000)
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(12,3))
ax.set_title(f'start={mu}, \u03C3={sigma}')
ax.hist(d, 50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
ax.set_xlim([mu,mu+8*sigma])
x = np.linspace(mu,mu+8*sigma,100000)
ax.plot(x,stats.expon.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
int_base1 = np.linspace(0,1.8,1000)
ax.fill_between(int_base1, stats.expon.pdf(int_base1,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .4)
ax2.set_yscale('log')
ax2.set_title(f'start={mu}, \u03C3={sigma}')
ax2.hist(d, 50, density=True, color = 'r', alpha = .3)
ax2.tick_params(labelsize = 10)
ax2.set_xlim([mu,mu+8*sigma])
x = np.linspace(mu,mu+8*sigma,100000)
ax2.plot(x,stats.expon.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
int_base1 = np.linspace(0,1.8,1000)
ax2.fill_between(int_base1, stats.expon.pdf(int_base1,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .4)
ax2.set_ylabel("Counts (log-scale)", fontsize=12); ax.set_ylabel("Counts", fontsize = 12)
ax2.set_xlabel("X", fontsize=12); ax.set_xlabel("X", fontsize = 12)
prob = 1 - stats.expon.cdf(1.8, loc=mu, scale=sigma)
z = (stats.norm.ppf(1-(prob)/2))
print(f'Percentage of hits that falsely appear as signal: {prob} || sigma value for this percentage: {z:.4f}')
# Out:
# Percentage of hits that falsely appear as signal: 0.04978706836786395 || sigma value for this percentage: 1.9618

# %%
mu = 2; sigma = .2
d = stats.expon.rvs(loc = mu, scale = sigma, size = 100000)
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(10,3))
ax.set_title(f'start={mu}, \u03C3={sigma}')
ax.hist(d, 50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
ax.set_xlim([mu,mu+8*sigma])
x = np.linspace(mu,mu+8*sigma,100000)
ax.plot(x,stats.expon.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
int_base1 = np.linspace(mu,2.85,1000)
ax.fill_between(int_base1, stats.expon.pdf(int_base1,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .4)
ax2.set_yscale('log')
ax2.set_title(f'start={mu}, \u03C3={sigma}')
ax2.hist(d, 50, density=True, color = 'r', alpha = .3)
ax2.tick_params(labelsize = 10)
ax2.set_xlim([mu,mu+8*sigma])
x = np.linspace(mu,mu+8*sigma,100000)
ax2.plot(x,stats.expon.pdf(x,loc = mu, scale = sigma),linewidth = 3,alpha = 0.5)
int_base1 = np.linspace(mu,2.85,1000)
ax2.fill_between(int_base1, stats.expon.pdf(int_base1,loc = mu, scale = sigma), color = 'b', linewidth = 0, alpha = .4)
ax2.set_ylabel("Counts (log-scale)", fontsize=12); ax.set_ylabel("Counts", fontsize = 12)
ax2.set_xlabel("X", fontsize=12); ax.set_xlabel("X", fontsize = 12)
prob = 1 - stats.expon.cdf(1.8, loc=mu, scale=sigma)
z = (stats.norm.ppf(1-(prob)/2))
print(f'Percentage of hits that falsely appear as signal: {prob} || sigma value for this percentage: {z:.4f}')
# Out:
# Percentage of hits that falsely appear as signal: 1.0 || sigma value for this percentage: 0.0000

# %% [markdown]
# Looking at the graphs, it is seen that changing the location of the distribution shifts the x value in which the peak is located and that the 'scale' or $\lambda$ changes the rate at which the distribution declines.

# %% [markdown]
# # Non-continuous Distributions

# %% [markdown]
# ## 1. A)

# %% [markdown]
# I have chosen to study the Poisson Distribution. This is much like the exponential distribution but it is discrete. Both distributions stem from a collection of a number of 'events' in a certain period of time, given that these events happen at an average constant rate and the events have no effect on each other. This distribution is represented by the PMF (similar to PDF) shown below.
# ### ${\displaystyle {\frac {\lambda ^{k}e^{-\lambda }}{k!}}}{\displaystyle }$

# %% [markdown]
# ## 1. B)

# %%
mu = 4; offset = 0
d = stats.poisson.rvs(mu, offset, size = 100000)
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(12,3))
ax.set_title(f'Average={mu}, offset={offset}')
#ax.hist(d, 50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
#ax.set_xlim([mu,mu+5*offset])
x = np.linspace(0, 15,16)
ax.plot(x,stats.poisson.pmf(x, mu, offset), 'r.', alpha = 1)
ax.vlines(x, 0, stats.poisson.pmf(x, mu, offset), colors='r', lw=5, alpha=0.5)
ax2.set_yscale('log')
ax2.set_title(f'Average={mu}, offset={offset}')
#ax2.hist(d, 50, density=True, color = 'r', alpha = .3)
ax2.tick_params(labelsize = 10)
#ax2.set_xlim([mu,mu+5*offset])
ax2.plot(x,stats.poisson.pmf(x, mu, offset), 'r.' ,alpha = 1)
ax2.vlines(x, 0, stats.poisson.pmf(x, mu, offset), colors='r', lw=5, alpha=0.5)
ax2.set_ylabel("Counts (log-scale)", fontsize=12); ax.set_ylabel("Counts", fontsize = 12)
ax2.set_xlabel("X", fontsize=12); ax.set_xlabel("X", fontsize = 12)
# Out:
# Text(0.5, 0, 'X')

# %%
mu = 15; offset = 2
d = stats.poisson.rvs(mu, offset, size = 100000)
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(12,3))
ax.set_title(f'Average={mu}, offset={offset}')
#ax.hist(d, 50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
#ax.set_xlim([mu,mu+5*offset])
x = np.linspace(0, 2*mu-1,2*mu)
ax.plot(x,stats.poisson.pmf(x, mu, offset), 'r.', alpha = 1)
ax.vlines(x, 0, stats.poisson.pmf(x, mu, offset), colors='r', lw=3, alpha=0.5)
ax2.set_yscale('log')
ax2.set_title(f'Average={mu}, offset={offset}')
#ax2.hist(d, 50, density=True, color = 'r', alpha = .3)
ax2.tick_params(labelsize = 10)
#ax2.set_xlim([mu,mu+5*offset])
ax2.plot(x,stats.poisson.pmf(x, mu, offset), 'r.' ,alpha = 1)
ax2.vlines(x, 0, stats.poisson.pmf(x, mu, offset), colors='r', lw=3, alpha=0.5)
ax2.set_ylabel("Counts (log-scale)", fontsize=12); ax.set_ylabel("Counts", fontsize = 12)
ax2.set_xlabel("X", fontsize=12); ax.set_xlabel("X", fontsize = 12)
# Out:
# Text(0.5, 0, 'X')

# %% [markdown]
# These plots show that the average of the distribution has an effect on the overall shape, but that changing the 'offset' of the distribution essentially just shifts the distribution right or left. Another interesting note is that the average of the distribution is not neccesarily the most likely number to hit depending on the distribution parameters.

# %% [markdown]
# ## 1. C)

# %% [markdown]
# Now the experimental question to be answered for the Poisson distribution goes something like this: "What is the probability that (6, 25) or more events will occur in a given time frame?"

# %%
mu = 4; offset = 0
d = stats.poisson.rvs(mu, offset, size = 100000)
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(12,3))
ax.set_title(f'Average={mu}, offset={offset}')
#ax.hist(d, 50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
#ax.set_xlim([mu,mu+5*offset])
x = np.linspace(0, 2*mu,2*mu+1)
ax.plot(x,stats.poisson.pmf(x, mu, offset), 'r.', alpha = 1)
ax.vlines(x, 0, stats.poisson.pmf(x, mu, offset), colors='r', lw=5, alpha=0.5)
ax2.set_yscale('log')
ax2.set_title(f'Average={mu}, offset={offset}')
#ax2.hist(d, 50, density=True, color = 'r', alpha = .3)
ax2.tick_params(labelsize = 10)
#ax2.set_xlim([mu,mu+5*offset])
ax2.plot(x,stats.poisson.pmf(x, mu, offset), 'r.' ,alpha = 1)
ax2.vlines(x, 0, stats.poisson.pmf(x, mu, offset), colors='r', lw=5, alpha=0.5)
ax2.set_ylabel("Counts (log-scale)", fontsize=12); ax.set_ylabel("Counts", fontsize = 12)
ax2.set_xlabel("X", fontsize=12); ax.set_xlabel("X", fontsize = 12)
base = np.linspace(0, 6,7)
ax.fill_between(base, stats.poisson.pmf(base, mu, offset), color = 'b', linewidth = 1, alpha = .4)
ax2.fill_between(base, stats.poisson.pmf(base, mu, offset), color = 'b', linewidth = 1, alpha = .4)
prob = 1 - stats.poisson.cdf(6, mu, offset)
z = (stats.norm.ppf(1-(prob)/2))
print(f'Percentage of hits that falsely appear as signal: {prob:.4f} || sigma value for this percentage: {z:.4f}')
# Out:
# Percentage of hits that falsely appear as signal: 0.1107 || sigma value for this percentage: 1.5952

# %%
mu = 15; offset = 2; sigma = 14
d = stats.poisson.rvs(mu, offset, size = 100000)
fig, (ax, ax2) = plt.subplots(1, 2, figsize=(12,3))
ax.set_title(f'Average={mu}, offset={offset}')
#ax.hist(d, 50, density=True, color = 'r', alpha = .3)
ax.tick_params(labelsize = 10)
#ax.set_xlim([mu,mu+5*offset])
x = np.linspace(0, 2*mu,2*mu+1)
ax.plot(x,stats.poisson.pmf(x, mu, offset), 'r.', alpha = 1)
ax.vlines(x, 0, stats.poisson.pmf(x, mu, offset), colors='r', lw=3, alpha=0.5)
ax2.set_yscale('log')
ax2.set_title(f'Average={mu}, offset={offset}')
#ax2.hist(d, 50, density=True, color = 'r', alpha = .3)
ax2.tick_params(labelsize = 10)
#ax2.set_xlim([mu,mu+5*offset])
ax2.plot(x,stats.poisson.pmf(x, mu, offset), 'r.' ,alpha = 1)
ax2.vlines(x, 0, stats.poisson.pmf(x, mu, offset), colors='r', lw=3, alpha=0.5)
ax2.set_ylabel("Counts (log-scale)", fontsize=12); ax.set_ylabel("Counts", fontsize = 12)
ax2.set_xlabel("X", fontsize=12); ax.set_xlabel("X", fontsize = 12)
base = np.linspace(0, 25,26)
ax.fill_between(base, stats.poisson.pmf(base, mu, offset), color = 'b', linewidth = 1, alpha = .4)
ax2.fill_between(base, stats.poisson.pmf(base, mu, offset), color = 'b', linewidth = 1, alpha = .4)
prob = 1 - stats.poisson.cdf(25, mu, offset)
z = (stats.norm.ppf(1-(prob)/2))
print(f'Percentage of hits that falsely appear as signal: {prob} || sigma value for this percentage: {z:.4f}')
# Out:
# Percentage of hits that falsely appear as signal: 0.019464574372022758 || sigma value for this percentage: 2.3365

# %% [markdown]
# ## 1. D)

# %% [markdown]
# Because of discrete data and distribution, the probabilities associated with the data and the sigma values are also discrete. This means that  your 'possible false signal' probability can change by a lot if you were to change your selection criteria by just one value.

# %% [markdown]
# ## 1. E)

# %% [markdown]
# It is not that surprising that parameters like the mean of a Poisson distribution are not necessarily discrete. In any average of a set of integers, there is the possibility to have a non-integer mean. Values involving sums of data from the distribution will be discrete (probabilities, sigma values, etc.) but values that operate on these sums such as averages do not have to fall under the integer values of the data.
